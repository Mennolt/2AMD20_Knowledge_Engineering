# %%
import pandas as pd

# %%
data = pd.read_csv("NLG Recipe dataset/dataset/first_tenth_recipes.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# ...

# %%
data["ingredients"][0]
# Out:
# '["1 c. firmly packed brown sugar", "1/2 c. evaporated milk", "1/2 tsp. vanilla", "1/2 c. broken nuts (pecans)", "2 Tbsp. butter or margarine", "3 1/2 c. bite size shredded rice biscuits"]'

# %%
data["NER"][0]
# Out:
# '["brown sugar", "milk", "vanilla", "nuts", "butter", "bite size shredded rice biscuits"]'

# %%
#nr null values, duplicate titles or links
data.isnull().sum()
# Out:
# Unnamed: 0     0
# title          0
# ingredients    0
# directions     0
# link           0
# source         0
# NER            0
# dtype: int64

# %%
print([len(data[i].unique()) for i in data.columns], len(data))
# Out:
# [223114, 98155, 222885, 222161, 223114, 1, 215058] 223114

# %%
mask = data["directions"].duplicated()

# %%
data1 = data[mask].copy()
data1.sort_values("directions", inplace = True)

# %%
data1.head(20)
# Out:
#         Unnamed: 0                                              title  \
# 140332      140332                                         Baby Wipes
# 201437      201437  Mom'S Banana Bread(Yield: 1 Loaf Or 12 Small M...
# 70259        70259      Lemon Cake Squares(Yield: 24 Large Squares)
# 132331      132331                      Banana Bread(Yield: 1 Loaf)
# 125577      125577  Daddy'S Favorite Sloppy Joes(Yield: 4 Big Or 6...
# 123590      123590  Nana'S Brownies(Yield: Depends On How You Cut ...
# 202467      202467       Sour Cream Coffee Cake(Yield: 12 Servings)
# 100605      100605           Googie'S Banana Bread(Yield: 2 Loaves)
# 209646      209646            Toffy Squares(Yield: 2 Dozen Or More)
# 94887        94887  Farmhouse Barbecue Muffins(Yield:  8 - 10 Muff...
# 216622      216622             Pizza Pinwheels(Yield: 16 Pinwheels)
# 142060      142060                                           Taco Mix
# 213892      213892                                     Scalloped Corn
# ...

# %%
mask = data[["directions","title"]].duplicated(keep = False)
sum(mask)
# Out:
# 123

# %%
data2 = data[mask].copy()
data2.sort_values("title", inplace = True)
data2.head(50)
# Out:
#         Unnamed: 0                          title  \
# 164763      164763                    5 Cup Salad
# 122109      122109                    5 Cup Salad
# 170651      170651                    Apple Salad
# 145769      145769                    Apple Salad
# 157403      157403  Bacon Wrapped Water Chestnuts
# 37114        37114  Bacon Wrapped Water Chestnuts
# 219989      219989                 Barbecue Sauce
# 169963      169963                 Barbecue Sauce
# 63294        63294                 Barbecue Sauce
# 43555        43555                 Barbecue Sauce
# 125671      125671                     Bean Salad
# 2947          2947                     Bean Salad
# 40478        40478            Beef 'N Potato Bake
# 174358      174358            Beef 'N Potato Bake
# 51827        51827                 Broccoli Salad
# 29912        29912                 Broccoli Salad
# 36222        36222                 Broccoli Salad
# 103960      103960                 Broccoli Salad
# ...

# %%
#get ingredient csv
data = pd.read_csv("NLG Recipe dataset/dataset/first_tenth_recipes.csv")
